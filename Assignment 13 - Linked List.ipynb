# %% [markdown]
# Question 1
#
# Given two linked list of the same size, the task is to create a new linked list using those linked lists. The condition is that the greater node among both linked list will be added to the new linked list.
#
# Examples:
#
# ```
# Input: list1 = 5->2->3->8
# list2 = 1->7->4->5
# Output: New list = 5->7->4->8
#
# Input:list1 = 2->8->9->3
# list2 = 5->3->6->4
# Output: New list = 5->8->9->4
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head
    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next
    return head

def mergeLinkedLists(list1, list2):
    if not list1 or not list2:
        return None

    new_head = Node(max(list1.data, list2.data))
    new_current = new_head
    current1 = list1.next
    current2 = list2.next

    while current1 and current2:
        new_node = Node(max(current1.data, current2.data))
        new_current.next = new_node
        new_current = new_current.next
        current1 = current1.next
        current2 = current2.next

    return new_head

values1 = input("values1: ").split()
values2 = input("values2: ").split()

list1 = createLinkedList(values1)
list2 = createLinkedList(values2)

new_list = mergeLinkedLists(list1, list2)

current = new_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# values1: 5 2 3 8
# values2: 1 7 4 5
# 5 7 4 8

# %% [markdown]
# Question 2
#
# Write a function that takes a list sorted in non-decreasing order and deletes any duplicate nodes from the list. The list should only be traversed once.
#
# For example if the linked list is 11->11->11->21->43->43->60 then removeDuplicates() should convert the list to 11->21->43->60.
#
# Example 1:
#
# ```
# Input:
# LinkedList:
# 11->11->11->21->43->43->60
# Output:
# 11->21->43->60
# ```
#
# Example 2:
#
# Input:
# LinkedList:
# 10->12->12->25->25->25->34
# Output:
# 10->12->25->34

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def createLinkedList(values):
    if not values:
        return None
    head = Node(values[0])
    current = head
    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next
    return head

def removeDuplicates(head):
    if not head:
        return None
    current = head
    while current.next:
        if current.data == current.next.data:
            current.next = current.next.next
        else:
            current = current.next
    return head
values = input("Enter the values: ").split()
linked_list = createLinkedList(values)
new_linked_list = removeDuplicates(linked_list)
current = new_linked_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# Enter the values: 11 11 11 21 43 43
# 11 21 43

# %% [markdown]
# Question 3
#
# Given a linked list of size N. The task is to reverse every k nodes (where k is an input to the function) in the linked list. If the number of nodes is not a multiple of *k* then left-out nodes, in the end, should be considered as a group and must be reversed (See Example 2 for clarification).
#
# Example 1:
#
# ```
# Input:
# LinkedList: 1->2->2->4->5->6->7->8
# K = 4
# Output:4 2 2 1 8 7 6 5
# Explanation:
# The first 4 elements 1,2,2,4 are reversed first
# and then the next 4 elements 5,6,7,8. Hence, the
# resultant linked list is 4->2->2->1->8->7->6->5.
#
# ```
#
# Example 2:
#
# ```
# Input:
# LinkedList: 1->2->3->4->5
# K = 3
# Output:3 2 1 5 4
# Explanation:
# The first 3 elements are 1,2,3 are reversed
# first and then elements 4,5 are reversed.Hence,
# the resultant linked list is 3->2->1->5->4.
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next

    return head


def reverseKNodes(head, k):
    if not head or k == 1:
        return head

    dummy = Node(0)
    dummy.next = head
    prev = dummy

    while prev:
        prev = reverseNextKNodes(prev, k)

    return dummy.next


def reverseNextKNodes(prev, k):
    current = prev.next
    next_node = None
    tail = prev.next

    for _ in range(k):
        if not tail:
            return None
        tail = tail.next

    for _ in range(k):
        next_node = current.next
        current.next = prev.next
        prev.next = current
        current = next_node
    tail.next = current

    return tail

values = input("values: ").split()
k = int(input("k: "))
linked_list = createLinkedList(values)
new_linked_list = reverseKNodes(linked_list, k)
current = new_linked_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# values: 1 2 3 4 5
# k: 3

# %% [markdown]
# Question 4
#
# Given a linked list, write a function to reverse every alternate k nodes (where k is an input to the function) in an efficient way. Give the complexity of your algorithm.
#
# Example:
#
# ```
# Inputs:   1->2->3->4->5->6->7->8->9->NULL and k = 3
# Output:   3->2->1->4->5->6->9->8->7->NULL.
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next

    return head


def reverseAlternateKNodes(head, k):
    if not head:
        return None

    current = head
    prev = None
    next_node = None
    count = 0
    while current and count < k:
        next_node = current.next
        current.next = prev
        prev = current
        current = next_node
        count += 1

    count = 0
    while current and count < k:
        current = current.next
        count += 1

    if current:
        head.next = reverseAlternateKNodes(current, k)

    return prev

values = input("Values: ").split()
k = int(input("k: "))

linked_list = createLinkedList(values)

new_linked_list = reverseAlternateKNodes(linked_list, k)

current = new_linked_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# Values: 1 2 3 4 5 6 7 8 9
# k: 3
# 3 2 1 9 8 7

# %% [markdown]
# Question 5
#
# Given a linked list and a key to be deleted. Delete last occurrence of key from linked. The list may have duplicates.
#
# Examples:
#
# Input:   1->2->3->5->2->10, key = 2
# Output:  1->2->3->5->10

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next

    return head


def deleteLastOccurrence(head, key):
    if not head:
        return None

    last_occurrence = None
    current = head
    prev = None

    while current:
        if current.data == key:
            last_occurrence = current
        current = current.next

    if last_occurrence:
        if last_occurrence == head:
            head = head.next
        else:
            prev.next = last_occurrence.next

    return head

values = input("Values: ").split()
key = input("key: ")
linked_list = createLinkedList(values)
updated_linked_list = deleteLastOccurrence(linked_list, key)
current = updated_linked_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# Values: 1 2 3 4 5
# key: 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25392/3284596808.py in <module>
#      44 key = input("key: ")
#      45 linked_list = createLinkedList(values)
# ---> 46 updated_linked_list = deleteLastOccurrence(linked_list, key)
#      47 current = updated_linked_list
#      48 while current:
#
# ~\AppData\Local\Temp/ipykernel_25392/3284596808.py in deleteLastOccurrence(head, key)
#      37             head = head.next
#      38         else:
# ---> 39             prev.next = last_occurrence.next
#      40
#      41     return head
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %% [markdown]
# Question 6
#
# Given two sorted linked lists consisting of N and M nodes respectively. The task is to merge both of the lists (in place) and return the head of the merged list.
#
# Examples:
#
# Input: a: 5->10->15, b: 2->3->20
#
# Output: 2->3->5->10->15->20
#
# Input: a: 1->1, b: 2->4
#
# Output: 1->1->2->4

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        current = current.next

    return head


def mergeSortedLists(a, b):
    if not a:
        return b
    if not b:
        return a

    if a.data <= b.data:
        head = a
        a = a.next
    else:
        head = b
        b = b.next

    current = head

    # Merge the remaining nodes
    while a and b:
        if a.data <= b.data:
            current.next = a
            a = a.next
        else:
            current.next = b
            b = b.next
        current = current.next

    if a:
        current.next = a
    else:
        current.next = b

    return head

values_a = input("A: ").split()
values_b = input("B: ").split()

list_a = createLinkedList(values_a)
list_b = createLinkedList(values_b)

merged_list = mergeSortedLists(list_a, list_b)

current = merged_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# A: 5 10 15
# B: 2 3 20
# 2 3 20 5 10 15

# %% [markdown]
# Question 7
#
# Given a Doubly Linked List, the task is to reverse the given Doubly Linked List.
#
# Example:
#
# ```
# Original Linked list 10 8 4 2
# Reversed Linked list 2 4 8 10
# ```

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None


def createLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        new_node.prev = current
        current = current.next

    return head


def reverseDoublyLinkedList(head):
    if not head:
        return None

    current = head
    prev_node = None

    while current:
        temp = current.prev
        current.prev = current.next
        current.next = temp
        prev_node = current
        current = current.prev

    head = prev_node

    return head
values = input("values: ").split()
doubly_linked_list = createLinkedList(values)
reversed_list = reverseDoublyLinkedList(doubly_linked_list)
current = reversed_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# values: 10 8 4 2
# 2 4 8 10

# %% [markdown]
# Question 8
#
# Given a doubly linked list and a position. The task is to delete a node from given position in a doubly linked list.
#
# Example 1:
#
# ```
# Input:
# LinkedList = 1 <--> 3 <--> 4
# x = 3
# Output:1 3
# Explanation:After deleting the node at
# position 3 (position starts from 1),
# the linked list will be now as 1->3.
#
# ```
#
# Example 2:
#
# Input:
# LinkedList = 1 <--> 5 <--> 2 <--> 9
# x = 1
# Output:5 2 9

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None


def createDoublyLinkedList(values):
    if not values:
        return None

    head = Node(values[0])
    current = head

    for value in values[1:]:
        new_node = Node(value)
        current.next = new_node
        new_node.prev = current
        current = current.next

    return head


def deleteNode(head, position):
    if not head:
        return None
    if position == 1:
        new_head = head.next
        if new_head:
            new_head.prev = None
        return new_head

    current = head
    count = 1
    while current and count < position:
        current = current.next
        count += 1

    if not current:
        return head
    current.prev.next = current.next
    if current.next:
        current.next.prev = current.prev
    del current

    return head

values = input("Values: ").split()
position = int(input("x: "))
doubly_linked_list = createDoublyLinkedList(values)
updated_list = deleteNode(doubly_linked_list, position)
current = updated_list
while current:
    print(current.data, end=" ")
    current = current.next
# Out:
# Values: 1 3 4
# x: 3
# 1 3
