# %% [markdown]
# Question-1:
#
# Given preorder of a binary tree, calculate its **[depth(or height)](https://www.geeksforgeeks.org/write-a-c-program-to-find-the-maximum-depth-or-height-of-a-tree/)** [starting from depth 0]. The preorder is given as a string with two possible characters.
#
# 1. ‘l’ denotes the leaf
# 2. ‘n’ denotes internal node
#
# The given tree can be seen as a full binary tree where every node has 0 or two children. The two children of a node can ‘n’ or ‘l’ or mix of both.
#
# Examples :
#
# Input  : nlnll
# Output : 2
# Explanation :
#
# !https://media.geeksforgeeks.org/wp-content/uploads/btree1.png
#
# Input  : nlnnlll
# Output : 3
#
# !https://media.geeksforgeeks.org/wp-content/uploads/dia2.png

# %%
def calculate_depth(preorder):
    if len(preorder) == 0 or preorder[0] == 'l':
        return 0
    
    left_depth = calculate_depth(preorder[1:])
    right_depth = calculate_depth(preorder[left_depth + 1:])
    
    return max(left_depth, right_depth) + 1

preorder_input = input("Enter the preorder string representation of the binary tree: ")

depth = calculate_depth(preorder_input)

print("Depth:", depth)
# Out:
# Enter the preorder string representation of the binary tree: nlnll
# Depth: 1

# %% [markdown]
# Question-2:
#
# Given a Binary tree, the task is to print the left view of the Binary Tree. The left view of a Binary Tree is a set of leftmost nodes for every level.
#
# Examples:
#
# Input:
#
#             4
#
#           /   \
#
#         5     2
#
#              /   \
#
#             3     1
#
#            /  \
#
#           6    7
#
# Output: 4 5 3 6
#
# Explanation:
#
# !https://media.geeksforgeeks.org/wp-content/cdn-uploads/left-view.png
#
# Input:
#
#                     1
#
#                   /   \
#
#                 2       3
#
#                  \
#
#                    4
#
#                      \
#
#                         5
#
#                            \
#
#                              6
#
# Output: 1 2 4 5 6

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def print_left_view_util(node, level, max_level):
    if node is None:
        return

    if level > max_level[0]:
        print(node.data, end=" ")
        max_level[0] = level

    print_left_view_util(node.left, level + 1, max_level)
    print_left_view_util(node.right, level + 1, max_level)

def print_left_view(root):
    max_level = [0]
    print_left_view_util(root, 1, max_level)
root_data = int(input("Enter the value of the root node: "))
root = Node(root_data)
stack = [root]
while stack:
    current = stack.pop()
    left_data = input(f"Enter the value of the left child of {current.data} (or 'None'): ")
    if left_data != 'None':
        current.left = Node(int(left_data))
        stack.append(current.left)

    right_data = input(f"Enter the value of the right child of {current.data} (or 'None'): ")
    if right_data != 'None':
        current.right = Node(int(right_data))
        stack.append(current.right)

print("Left view:")
print_left_view(root)
# Out:
# Enter the value of the root node: 4
# Enter the value of the left child of 4 (or 'None'): 5
# Enter the value of the right child of 4 (or 'None'): 2
# Enter the value of the left child of 2 (or 'None'): None
# Enter the value of the right child of 2 (or 'None'): None
# Enter the value of the left child of 5 (or 'None'): 3
# Enter the value of the right child of 5 (or 'None'): 1
# Enter the value of the left child of 1 (or 'None'): 6
# Enter the value of the right child of 1 (or 'None'): 7
# Enter the value of the left child of 7 (or 'None'): None
# Enter the value of the right child of 7 (or 'None'): None
# Enter the value of the left child of 6 (or 'None'): None
# Enter the value of the right child of 6 (or 'None'): None
# Enter the value of the left child of 3 (or 'None'): None
# Enter the value of the right child of 3 (or 'None'): None
# Left view:
# 4 5 3 6

# %% [markdown]
# Question-3:
#
# Given a Binary Tree, print the Right view of it.
#
# The right view of a Binary Tree is a set of nodes visible when the tree is visited from the Right side.
#
# Examples:
#
# Input:
#
#          1
#
#       /     \
#
#    2         3
#
# /   \       /  \
#
# 4     5   6    7
#
#              \
#
#                8
#
# Output:
#
# Right view of the tree is 1 3 7 8
#
# Input:
#
#          1
#
#        /
#
#     8
#
#   /
#
# 7
#
# Output:
#
# Right view of the tree is 1 8 7

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def print_right_view_util(node, level, max_level):
    if node is None:
        return

    if level > max_level[0]:
        print(node.data, end=" ")
        max_level[0] = level

    print_right_view_util(node.right, level + 1, max_level)
    print_right_view_util(node.left, level + 1, max_level)

def print_right_view(root):
    max_level = [0]
    print_right_view_util(root, 1, max_level)

# Create the binary tree
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.right.left = Node(6)
root.right.right = Node(7)
root.right.right.right = Node(8)

print("Right view:")
print_right_view(root)
# Out:
# Right view:
# 1 3 7 8

# %% [markdown]
# Question-4:
#
# Given a Binary Tree, The task is to print the bottom view from left to right. A node x is there in output if x is the bottommost node at its horizontal distance. The horizontal distance of the left child of a node x is equal to a horizontal distance of x minus 1, and that of a right child is the horizontal distance of x plus 1.
#
# Examples:
#
# Input:
#
#              20
#
#            /     \
#
#         8         22
#
#     /      \         \
#
# 5         3        25
#
#         /    \
#
#    10       14
#
# Output: 5, 10, 3, 14, 25.
#
# Input:
#
#              20
#
#            /     \
#
#         8         22
#
#     /      \      /   \
#
#  5         3    4     25
#
#          /    \
#
#      10       14
#
# Output:
#
# 5 10 4 14 25.
#
# Explanation:
#
# If there are multiple bottom-most nodes for a horizontal distance from the root, then print the later one in the level traversal.
#
# 3 and 4 are both the bottom-most nodes at a horizontal distance of 0, we need to print 4.

# %%
from collections import deque

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        self.hd = 0

def print_bottom_view(root):
    if root is None:
        return

    hd_dict = {}  
    queue = deque([(root, 0)])  

    while queue:
        node, hd = queue.popleft()
        node.hd = hd

        hd_dict[hd] = node.data

        if node.left:
            queue.append((node.left, hd - 1))
        if node.right:
            queue.append((node.right, hd + 1))
    bottom_view = [hd_dict[hd] for hd in sorted(hd_dict.keys())]
    print("Bottom view:", ' '.join(map(str, bottom_view)))

root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(5)
root.left.right = Node(3)
root.right.right = Node(25)
root.left.right.left = Node(10)
root.left.right.right = Node(14)

print_bottom_view(root)
# Out:
# Bottom view: 5 10 3 14 25
